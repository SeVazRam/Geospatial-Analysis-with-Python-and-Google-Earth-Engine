# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import requests
import os
import glob
import numpy as np

# %%
geo_df = gpd.read_file("https://gist.githubusercontent.com/walkerke/76cb8cc5f949432f9555/raw/363c297ce82a4dcb9bdf003d82aa4f64bc695cf1/mx.geojson")
geo_df.head()
# Out:
#    id                 name                state  mus09  pri10  sec10  ter10  \
# 0   1       Aguascalientes       Aguascalientes   17.1   6.34  28.74  64.28
# 1   2      Baja California      Baja California   15.4   5.44  31.64  61.68
# 2   3  Baja California Sur  Baja California Sur    3.0   9.18  17.48  72.37
# 3   4             Campeche             Campeche    7.0  19.24  21.20  57.11
# 4   5              Chiapas              Chiapas   13.9  42.76  13.51  42.90
#
#     gdp08  other10                                           geometry
# 0   84.70     0.64  MULTIPOLYGON (((-102.21140 22.35450, -102.1908...
# 1   83.07     1.24  MULTIPOLYGON (((-114.09429 28.02418, -114.0774...
# 2   94.64     0.97  MULTIPOLYGON (((-109.79843 24.15516, -109.8028...
# 3  395.55     2.45  MULTIPOLYGON (((-91.52440 18.76659, -91.52457 ...
# 4   34.44     0.83  MULTIPOLYGON (((-93.97061 16.00979, -93.96390 ...

# %%
#plt.grid()
#geo_df.plot()

# %%
data_path = os.getcwd()+ '/Data/Temp/2021/'
db_data_path = data_path 
os.listdir()
print(os.listdir(db_data_path))
# Out:
# ['202101010000TMed.csv', '202102010000TMed.csv', '202103010000TMed.csv', '202104010000TMed.csv', '202105010000TMed.csv', '202106010000TMed.csv', '202107010000TMed.csv', '202108010000TMed.csv', '202109010000TMed.csv', '202110010000TMed.csv', '202111010000TMed.csv', '202112010000TMed.csv']

# %%
path = os.getcwd()+ '/Data/Temp/2021/'
all_files = glob.glob(path+'*.csv')
all_files
# Out:
# ['C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202101010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202102010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202103010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202104010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202105010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202106010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202107010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202108010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202109010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202110010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202111010000TMed.csv',
#  'C:\\Users\\sebas\\OneDrive\\Escritorio\\ARCGIS/Data/Temp/2021\\202112010000TMed.csv']

# %%
#dfPrueba=[df1,df2]
li = []
TMed = ['TMed202101','TMed202102','TMed202103','TMed202104','TMed202105','TMed202106','TMed202107','TMed202108','TMed202109',
        'TMed202110','TMed202111','TMed202112' ]

# %%
for i in range(len(TMed)):
    df = pd.read_csv(all_files[i], encoding='latin-1')
    df = df.rename(columns={'Tmed':TMed[i]})
    li.append(df)
    
li[0].head()
# Out:
#       Lon    Lat     Clave  Edo                                  Est  \
# 0 -102.79  21.81     MNLAG  AGS                      Media Luna Ags.
# 1 -102.71  21.85  CALVILLO  AGS                   Calvillo Ags. SMN*
# 2 -102.29  21.85     OBSAG  AGS  Observatorio de Aguascalientes Ags.
# 3 -102.31  21.90     AGSAG  AGS                  Aguascalientes Ags.
# 4 -101.99  21.90     CNSAG  AGS                       Los Conos Ags.
#
#    TMed202101
# 0        13.8
# 1        15.2
# 2        15.1
# 3        15.3
# 4        13.1

# %%
d1=li[0]
d2=li[1]
d3=li[2]
d4=li[3]
d5=li[4]
d6=li[5]
d7=li[6]
d8=li[7]
d9=li[8]
d10=li[9]
d11=li[10]
d12=li[11]
#len(d1),len(d2)

# %%
df_outer = pd.merge(d1,d2,
              on=['Clave','Lon','Lat','Est','Edo'], how='outer')

df_outer = pd.merge(df_outer , d3, on=['Clave','Lon','Lat','Est','Edo'], how='outer')

#pd.concat(li,axis=0,ignore_index=True)
df_outer.head()
# Out:
#       Lon    Lat     Clave  Edo                                  Est  \
# 0 -102.79  21.81     MNLAG  AGS                      Media Luna Ags.
# 1 -102.71  21.85  CALVILLO  AGS                   Calvillo Ags. SMN*
# 2 -102.29  21.85     OBSAG  AGS  Observatorio de Aguascalientes Ags.
# 3 -102.31  21.90     AGSAG  AGS                  Aguascalientes Ags.
# 4 -101.99  21.90     CNSAG  AGS                       Los Conos Ags.
#
#    TMed202101  TMed202102  TMed202103
# 0        13.8        15.8        18.6
# 1        15.2        17.2        20.1
# 2        15.1        16.9        20.1
# 3        15.3        17.2        20.9
# 4        13.1        15.0        17.9

# %%
from functools import reduce
dfl=[d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12]
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Clave','Lon','Lat','Est','Edo'],
                                            how='outer'), dfl)

df_merged
# Out:
#          Lon    Lat         Clave    Edo  \
# 0    -102.79  21.81         MNLAG    AGS
# 1    -102.71  21.85      CALVILLO    AGS
# 2    -102.29  21.85         OBSAG    AGS
# 3    -102.31  21.90         AGSAG    AGS
# 4    -101.99  21.90         CNSAG    AGS
# ...      ...    ...           ...    ...
# 1622  -92.98  18.12       ELMANGO    TAB
# 1623  -98.84  26.31      SANJUAN2  TAMPS
# 1624  -95.97  19.04   ELSALADOMAR    VER
# 1625  -96.16  19.07       ELTEJAR    VER
# 1626 -103.65  23.47  SOMBRERETEob    ZAC
#
#                                        Est  TMed202101  TMed202102  \
# 0                          Media Luna Ags.        13.8        15.8
# 1                       Calvillo Ags. SMN*        15.2        17.2
# 2      Observatorio de Aguascalientes Ags.        15.1        16.9
# 3                      Aguascalientes Ags.        15.3        17.2
# 4                           Los Conos Ags.        13.1        15.0
# ...                                    ...         ...         ...
# 1622                    El Mango Tab. SGT*         NaN         NaN
# 1623                  San Juan Tamps. SGT*         NaN         NaN
# 1624                 El Salado Ver. SEMAR*         NaN         NaN
# 1625                    El Tejar Ver. SGT*         NaN         NaN
# 1626  Observatorio de Sombrerete Zac. SMN*         NaN         NaN
#
#       TMed202103  TMed202104  TMed202105  TMed202106  TMed202107  TMed202108  \
# 0           18.6        20.4        23.0        23.4        22.0        22.1
# 1           20.1        21.5        24.1        23.5        22.1        22.1
# 2           20.1        22.3        23.3        22.3        21.6        22.0
# 3           20.9        23.0        23.8        22.2        21.9        22.0
# 4           17.9        19.6        20.9        20.4        19.7        19.9
# ...          ...         ...         ...         ...         ...         ...
# 1622         NaN         NaN         NaN         NaN         NaN         NaN
# 1623         NaN         NaN         NaN         NaN         NaN         NaN
# 1624         NaN         NaN         NaN         NaN         NaN         NaN
# 1625         NaN         NaN         NaN         NaN         NaN         NaN
# 1626         NaN         NaN         NaN         NaN         NaN         NaN
#
#       TMed202109  TMed202110  TMed202111  TMed202112
# 0           21.4        20.2        17.4         NaN
# 1           21.7        20.5        17.2        15.9
# 2           21.4        20.4        16.8        15.7
# 3           21.3        20.3        17.5        16.7
# 4           19.3        17.9        15.0        14.4
# ...          ...         ...         ...         ...
# 1622         NaN         NaN         NaN        25.2
# 1623         NaN         NaN         NaN        21.4
# 1624         NaN         NaN         NaN        24.8
# 1625         NaN         NaN         NaN        24.9
# 1626         NaN         NaN         NaN        14.4
#
# [1627 rows x 17 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1627 entries, 0 to 1626
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Lon         1627 non-null   float64
#  1   Lat         1627 non-null   float64
#  2   Clave       1626 non-null   object
#  3   Edo         1626 non-null   object
#  4   Est         1626 non-null   object
#  5   TMed202101  1263 non-null   float64
#  6   TMed202102  1294 non-null   float64
#  7   TMed202103  1334 non-null   float64
#  8   TMed202104  1312 non-null   float64
#  9   TMed202105  1305 non-null   float64
#  10  TMed202106  1383 non-null   float64
#  11  TMed202107  1375 non-null   float64
#  12  TMed202108  1356 non-null   float64
#  13  TMed202109  1371 non-null   float64
#  14  TMed202110  1406 non-null   float64
#  15  TMed202111  1438 non-null   float64
#  16  TMed202112  1322 non-null   float64
# dtypes: float64(14), object(3)
# memory usage: 293.3+ KB

# %%
cols = ['TMed202101','TMed202102','TMed202103','TMed202104','TMed202105','TMed202106','TMed202107','TMed202108','TMed202109',
        'TMed202110','TMed202111','TMed202112']
df_merged['TMed'] = df_merged[cols].mean(axis=1)
df_merged
# Out:
#          Lon    Lat         Clave    Edo  \
# 0    -102.79  21.81         MNLAG    AGS
# 1    -102.71  21.85      CALVILLO    AGS
# 2    -102.29  21.85         OBSAG    AGS
# 3    -102.31  21.90         AGSAG    AGS
# 4    -101.99  21.90         CNSAG    AGS
# ...      ...    ...           ...    ...
# 1622  -92.98  18.12       ELMANGO    TAB
# 1623  -98.84  26.31      SANJUAN2  TAMPS
# 1624  -95.97  19.04   ELSALADOMAR    VER
# 1625  -96.16  19.07       ELTEJAR    VER
# 1626 -103.65  23.47  SOMBRERETEob    ZAC
#
#                                        Est  TMed202101  TMed202102  \
# 0                          Media Luna Ags.        13.8        15.8
# 1                       Calvillo Ags. SMN*        15.2        17.2
# 2      Observatorio de Aguascalientes Ags.        15.1        16.9
# 3                      Aguascalientes Ags.        15.3        17.2
# 4                           Los Conos Ags.        13.1        15.0
# ...                                    ...         ...         ...
# 1622                    El Mango Tab. SGT*         NaN         NaN
# 1623                  San Juan Tamps. SGT*         NaN         NaN
# 1624                 El Salado Ver. SEMAR*         NaN         NaN
# 1625                    El Tejar Ver. SGT*         NaN         NaN
# 1626  Observatorio de Sombrerete Zac. SMN*         NaN         NaN
#
#       TMed202103  TMed202104  TMed202105  TMed202106  TMed202107  TMed202108  \
# 0           18.6        20.4        23.0        23.4        22.0        22.1
# 1           20.1        21.5        24.1        23.5        22.1        22.1
# 2           20.1        22.3        23.3        22.3        21.6        22.0
# 3           20.9        23.0        23.8        22.2        21.9        22.0
# 4           17.9        19.6        20.9        20.4        19.7        19.9
# ...          ...         ...         ...         ...         ...         ...
# 1622         NaN         NaN         NaN         NaN         NaN         NaN
# 1623         NaN         NaN         NaN         NaN         NaN         NaN
# 1624         NaN         NaN         NaN         NaN         NaN         NaN
# 1625         NaN         NaN         NaN         NaN         NaN         NaN
# 1626         NaN         NaN         NaN         NaN         NaN         NaN
#
#       TMed202109  TMed202110  TMed202111  TMed202112       TMed
# 0           21.4        20.2        17.4         NaN  19.827273
# 1           21.7        20.5        17.2        15.9  20.091667
# 2           21.4        20.4        16.8        15.7  19.825000
# 3           21.3        20.3        17.5        16.7  20.175000
# 4           19.3        17.9        15.0        14.4  17.758333
# ...          ...         ...         ...         ...        ...
# 1622         NaN         NaN         NaN        25.2  25.200000
# 1623         NaN         NaN         NaN        21.4  21.400000
# 1624         NaN         NaN         NaN        24.8  24.800000
# 1625         NaN         NaN         NaN        24.9  24.900000
# 1626         NaN         NaN         NaN        14.4  14.400000
#
# [1627 rows x 18 columns]

# %%
geo_df1 = gpd.GeoDataFrame(df_merged, geometry=gpd.points_from_xy(df_merged.Lon, df_merged.Lat), crs="EPSG:4326")
geo_df1
# Out:
#          Lon    Lat         Clave    Edo  \
# 0    -102.79  21.81         MNLAG    AGS
# 1    -102.71  21.85      CALVILLO    AGS
# 2    -102.29  21.85         OBSAG    AGS
# 3    -102.31  21.90         AGSAG    AGS
# 4    -101.99  21.90         CNSAG    AGS
# ...      ...    ...           ...    ...
# 1622  -92.98  18.12       ELMANGO    TAB
# 1623  -98.84  26.31      SANJUAN2  TAMPS
# 1624  -95.97  19.04   ELSALADOMAR    VER
# 1625  -96.16  19.07       ELTEJAR    VER
# 1626 -103.65  23.47  SOMBRERETEob    ZAC
#
#                                        Est  TMed202101  TMed202102  \
# 0                          Media Luna Ags.        13.8        15.8
# 1                       Calvillo Ags. SMN*        15.2        17.2
# 2      Observatorio de Aguascalientes Ags.        15.1        16.9
# 3                      Aguascalientes Ags.        15.3        17.2
# 4                           Los Conos Ags.        13.1        15.0
# ...                                    ...         ...         ...
# 1622                    El Mango Tab. SGT*         NaN         NaN
# 1623                  San Juan Tamps. SGT*         NaN         NaN
# 1624                 El Salado Ver. SEMAR*         NaN         NaN
# 1625                    El Tejar Ver. SGT*         NaN         NaN
# 1626  Observatorio de Sombrerete Zac. SMN*         NaN         NaN
#
#       TMed202103  TMed202104  TMed202105  TMed202106  TMed202107  TMed202108  \
# 0           18.6        20.4        23.0        23.4        22.0        22.1
# 1           20.1        21.5        24.1        23.5        22.1        22.1
# 2           20.1        22.3        23.3        22.3        21.6        22.0
# 3           20.9        23.0        23.8        22.2        21.9        22.0
# 4           17.9        19.6        20.9        20.4        19.7        19.9
# ...          ...         ...         ...         ...         ...         ...
# 1622         NaN         NaN         NaN         NaN         NaN         NaN
# 1623         NaN         NaN         NaN         NaN         NaN         NaN
# 1624         NaN         NaN         NaN         NaN         NaN         NaN
# 1625         NaN         NaN         NaN         NaN         NaN         NaN
# 1626         NaN         NaN         NaN         NaN         NaN         NaN
#
#       TMed202109  TMed202110  TMed202111  TMed202112       TMed  \
# 0           21.4        20.2        17.4         NaN  19.827273
# 1           21.7        20.5        17.2        15.9  20.091667
# 2           21.4        20.4        16.8        15.7  19.825000
# 3           21.3        20.3        17.5        16.7  20.175000
# 4           19.3        17.9        15.0        14.4  17.758333
# ...          ...         ...         ...         ...        ...
# 1622         NaN         NaN         NaN        25.2  25.200000
# 1623         NaN         NaN         NaN        21.4  21.400000
# 1624         NaN         NaN         NaN        24.8  24.800000
# 1625         NaN         NaN         NaN        24.9  24.900000
# 1626         NaN         NaN         NaN        14.4  14.400000
#
#                          geometry
# 0     POINT (-102.79000 21.81000)
# 1     POINT (-102.71000 21.85000)
# 2     POINT (-102.29000 21.85000)
# 3     POINT (-102.31000 21.90000)
# 4     POINT (-101.99000 21.90000)
# ...                           ...
# 1622   POINT (-92.98000 18.12000)
# 1623   POINT (-98.84000 26.31000)
# 1624   POINT (-95.97000 19.04000)
# 1625   POINT (-96.16000 19.07000)
# 1626  POINT (-103.65000 23.47000)
#
# [1627 rows x 19 columns]

# %%
intersect = gpd.overlay(geo_df1, geo_df, how='intersection')
intersect
# Out:
#          Lon    Lat         Clave  Edo  \
# 0    -102.79  21.81         MNLAG  AGS
# 1    -102.71  21.85      CALVILLO  AGS
# 2    -102.29  21.85         OBSAG  AGS
# 3    -102.31  21.90         AGSAG  AGS
# 4    -101.99  21.90         CNSAG  AGS
# ...      ...    ...           ...  ...
# 1596 -102.34  23.29         VCOZC  ZAC
# 1597 -103.05  22.05         ZPTJL  JAL
# 1598 -102.68  22.90          MMZC  ZAC
# 1599 -102.86  22.12       TAYAHUA  ZAC
# 1600 -103.65  23.47  SOMBRERETEob  ZAC
#
#                                               Est  TMed202101  TMed202102  \
# 0                                 Media Luna Ags.        13.8        15.8
# 1                              Calvillo Ags. SMN*        15.2        17.2
# 2             Observatorio de Aguascalientes Ags.        15.1        16.9
# 3                             Aguascalientes Ags.        15.3        17.2
# 4                                  Los Conos Ags.        13.1        15.0
# ...                                           ...         ...         ...
# 1596                            Villa de Cos Zac.         NaN         NaN
# 1597                               El Zapote Jal.         NaN         NaN
# 1598  Aeropuerto Internacional de Zacatecas Zac.*         NaN         NaN
# 1599                            Tayahua Zac. SMN*         NaN         NaN
# 1600         Observatorio de Sombrerete Zac. SMN*         NaN         NaN
#
#       TMed202103  TMed202104  TMed202105  ...  id            name  \
# 0           18.6        20.4        23.0  ...   1  Aguascalientes
# 1           20.1        21.5        24.1  ...   1  Aguascalientes
# 2           20.1        22.3        23.3  ...   1  Aguascalientes
# 3           20.9        23.0        23.8  ...   1  Aguascalientes
# 4           17.9        19.6        20.9  ...   1  Aguascalientes
# ...          ...         ...         ...  ...  ..             ...
# 1596        18.0         NaN         NaN  ...  32       Zacatecas
# 1597         NaN         NaN         NaN  ...  32       Zacatecas
# 1598         NaN         NaN         NaN  ...  32       Zacatecas
# 1599         NaN         NaN         NaN  ...  32       Zacatecas
# 1600         NaN         NaN         NaN  ...  32       Zacatecas
#
#                state  mus09  pri10  sec10  ter10  gdp08  other10  \
# 0     Aguascalientes   17.1   6.34  28.74  64.28  84.70     0.64
# 1     Aguascalientes   17.1   6.34  28.74  64.28  84.70     0.64
# 2     Aguascalientes   17.1   6.34  28.74  64.28  84.70     0.64
# 3     Aguascalientes   17.1   6.34  28.74  64.28  84.70     0.64
# 4     Aguascalientes   17.1   6.34  28.74  64.28  84.70     0.64
# ...              ...    ...    ...    ...    ...    ...      ...
# 1596       Zacatecas   31.3  24.32  22.88  52.01  48.17     0.79
# 1597       Zacatecas   31.3  24.32  22.88  52.01  48.17     0.79
# 1598       Zacatecas   31.3  24.32  22.88  52.01  48.17     0.79
# 1599       Zacatecas   31.3  24.32  22.88  52.01  48.17     0.79
# 1600       Zacatecas   31.3  24.32  22.88  52.01  48.17     0.79
#
#                          geometry
# 0     POINT (-102.79000 21.81000)
# 1     POINT (-102.71000 21.85000)
# 2     POINT (-102.29000 21.85000)
# 3     POINT (-102.31000 21.90000)
# 4     POINT (-101.99000 21.90000)
# ...                           ...
# 1596  POINT (-102.34000 23.29000)
# 1597  POINT (-103.05000 22.05000)
# 1598  POINT (-102.68000 22.90000)
# 1599  POINT (-102.86000 22.12000)
# 1600  POINT (-103.65000 23.47000)
#
# [1601 rows x 28 columns]

# %%
grouped = intersect.groupby(['id','state'])['TMed'].agg('mean')
grouped.head()
# Out:
# id  state
# 1   Aguascalientes         17.430304
# 2   Baja California        19.847486
# 3   Baja California Sur    23.496387
# 4   Campeche               27.366970
# 5   Chiapas                24.839787
# Name: TMed, dtype: float64

# %%
merge = pd.merge(geo_df, grouped, on="id")
merge = merge.rename(columns={'TMed': 'TMed21'})
merge.head()
# Out:
#    id                 name                state  mus09  pri10  sec10  ter10  \
# 0   1       Aguascalientes       Aguascalientes   17.1   6.34  28.74  64.28
# 1   2      Baja California      Baja California   15.4   5.44  31.64  61.68
# 2   3  Baja California Sur  Baja California Sur    3.0   9.18  17.48  72.37
# 3   4             Campeche             Campeche    7.0  19.24  21.20  57.11
# 4   5              Chiapas              Chiapas   13.9  42.76  13.51  42.90
#
#     gdp08  other10                                           geometry  \
# 0   84.70     0.64  MULTIPOLYGON (((-102.21140 22.35450, -102.1908...
# 1   83.07     1.24  MULTIPOLYGON (((-114.09429 28.02418, -114.0774...
# 2   94.64     0.97  MULTIPOLYGON (((-109.79843 24.15516, -109.8028...
# 3  395.55     2.45  MULTIPOLYGON (((-91.52440 18.76659, -91.52457 ...
# 4   34.44     0.83  MULTIPOLYGON (((-93.97061 16.00979, -93.96390 ...
#
#       TMed21
# 0  17.430304
# 1  19.847486
# 2  23.496387
# 3  27.366970
# 4  24.839787

# %%
merge['TMed21'].max()
# Out:
# 27.481924828643578

# %%
import matplotlib.pyplot as plt

merge.plot(column='TMed21', figsize=(10,10),
           legend_kwds={'label': "TMed2021 per State", 'orientation': "horizontal"}, legend=True, cmap='OrRd',vmin=14.5, vmax=29.2)

plt.grid(linestyle = '--', linewidth = 0.5)
plt.xlabel("longitude")
plt.ylabel("Latitude")
plt.title("Temperature by state")
plt.savefig("TMed2021")

# %% [markdown]
# # Analisis por mes
#
# Agrupar la tabla merge con los meses e identificador por estado

# %%
grouped2 = intersect.groupby(['id','state'])[cols].agg('mean')
grouped2.head()
# Out:
#                         TMed202101  TMed202102  TMed202103  TMed202104  \
# id state
# 1  Aguascalientes        12.850000   14.841667   17.930435   19.350000
# 2  Baja California       13.283333   14.108000   13.703704   17.896154
# 3  Baja California Sur   16.969231   18.157692   18.950000   21.792308
# 4  Campeche              24.087500   25.143750   27.406250   29.664706
# 5  Chiapas               23.640000   23.830435   25.306944   26.871429
#
#                         TMed202105  TMed202106  TMed202107  TMed202108  \
# id state
# 1  Aguascalientes        20.447826   19.779167   18.924000   19.144000
# 2  Baja California       20.150000   24.125926   27.077778   26.932143
# 3  Baja California Sur   23.711538   26.807143   28.081481   28.969231
# 4  Campeche              29.831250   29.170588   29.017647   28.788235
# 5  Chiapas               26.623188   25.965714   26.089706   25.942647
#
#                         TMed202109  TMed202110  TMed202111  TMed202112
# id state
# 1  Aguascalientes        18.685185   17.703704   14.814815   14.365217
# 2  Baja California       26.100000   20.588462   18.740000   13.471429
# 3  Baja California Sur   27.633333   25.432143   22.980645   20.158065
# 4  Campeche              28.647059   28.311765   24.900000   25.347368
# 5  Chiapas               25.394521   25.370667   22.718310   22.903448

# %%
dfAñoMes2021 = pd.merge(merge, grouped2, on="id")
dfAñoMes2021
# Out:
#     id                 name                            state  mus09  pri10  \
# 0    1       Aguascalientes                   Aguascalientes   17.1   6.34
# 1    2      Baja California                  Baja California   15.4   5.44
# 2    3  Baja California Sur              Baja California Sur    3.0   9.18
# 3    4             Campeche                         Campeche    7.0  19.24
# 4    5              Chiapas                          Chiapas   13.9  42.76
# 5    6            Chihuahua                        Chihuahua   15.2  10.22
# 6    7             Coahuila             Coahuila de Zaragoza    5.7   6.24
# 7    8               Colima                           Colima   21.0  13.36
# 8    9     Distrito Federal                 Distrito Federal    4.8   0.68
# 9   10              Durango                          Durango   17.4  16.62
# 10  11           Guanajuato                       Guanajuato   25.1  12.72
